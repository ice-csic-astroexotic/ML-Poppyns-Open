# %% [markdown]
# # Data-representation, architecture and time-profiling tests for 1-parameter prediction
# This notebook produces the plots in fig. 4, 5, 13 and 14 for the data-representation, architecture and time-profiling tests performed in [Ronchi et al. 2021](https://ui.adsabs.harvard.edu/abs/2021ApJ...916..100R/abstract)).

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import time

from matplotlib.ticker import ScalarFormatter

import utilities.plot_settings

# %%
res = np.array([32, 128, 512])
batch_size = np.array([1, 4, 8, 16, 32, 64])
samples = np.array([4, 8, 16, 32, 64, 128, 256, 512, 1024])

# %% [markdown]
# # Multi-layer perceptron (MLP)

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/gc_p_lnn_accuracies.txt', sep=" ")
gc_p_ba32 = data["ba32"].to_numpy()
gc_p_ba128 = data["ba128"].to_numpy()
gc_p_ba512 = data["ba512"].to_numpy()

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/gc_pv_lnn_accuracies.txt', sep=" ")
gc_pv_ba32 = data["ba32"].to_numpy()
gc_pv_ba128 = data["ba128"].to_numpy()
gc_pv_ba512 = data["ba512"].to_numpy()

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/icrs_p_lnn_accuracies.txt', sep=" ")
icrs_p_ba32 = data["ba32"].to_numpy()
icrs_p_ba128 = data["ba128"].to_numpy()
icrs_p_ba512 = data["ba512"].to_numpy()

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/icrs_pv_lnn_accuracies.txt', sep=" ")
icrs_pv_ba32 = data["ba32"].to_numpy()
icrs_pv_ba128 = data["ba128"].to_numpy()
icrs_pv_ba512 = data["ba512"].to_numpy()

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/gc_p_lnn_timings.txt', sep=" ")
gc_p_ft32 = data["ft32"].to_numpy()
gc_p_ft128 = data["ft128"].to_numpy()
gc_p_ft512 = data["ft512"].to_numpy()
gc_p_bt32 = data["bt32"].to_numpy()
gc_p_bt128 = data["bt128"].to_numpy()
gc_p_bt512 = data["bt512"].to_numpy()

gc_p_ft32 = gc_p_ft32/batch_size
gc_p_ft128 = gc_p_ft128/batch_size
gc_p_ft512 = gc_p_ft512/batch_size
gc_p_bt32 = gc_p_bt32/batch_size
gc_p_bt128 = gc_p_bt128/batch_size
gc_p_bt512 = gc_p_bt512/batch_size

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/gc_pv_lnn_timings.txt', sep=" ")
gc_pv_ft32 = data["ft32"].to_numpy()
gc_pv_ft128 = data["ft128"].to_numpy()
gc_pv_ft512 = data["ft512"].to_numpy()
gc_pv_bt32 = data["bt32"].to_numpy()
gc_pv_bt128 = data["bt128"].to_numpy()
gc_pv_bt512 = data["bt512"].to_numpy()

gc_pv_ft32 = gc_pv_ft32/batch_size
gc_pv_ft128 = gc_pv_ft128/batch_size
gc_pv_ft512 = gc_pv_ft512/batch_size
gc_pv_bt32 = gc_pv_bt32/batch_size
gc_pv_bt128 = gc_pv_bt128/batch_size
gc_pv_bt512 = gc_pv_bt512/batch_size

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/icrs_p_lnn_timings.txt', sep=" ")
icrs_p_ft32 = data["ft32"].to_numpy()
icrs_p_ft128 = data["ft128"].to_numpy()
icrs_p_ft512 = data["ft512"].to_numpy()
icrs_p_bt32 = data["bt32"].to_numpy()
icrs_p_bt128 = data["bt128"].to_numpy()
icrs_p_bt512 = data["bt512"].to_numpy()

icrs_p_ft32 = icrs_p_ft32/batch_size
icrs_p_ft128 = icrs_p_ft128/batch_size
icrs_p_ft512 = icrs_p_ft512/batch_size
icrs_p_bt32 = icrs_p_bt32/batch_size
icrs_p_bt128 = icrs_p_bt128/batch_size
icrs_p_bt512 = icrs_p_bt512/batch_size

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/icrs_pv_lnn_timings.txt', sep=" ")
icrs_pv_ft32 = data["ft32"].to_numpy()
icrs_pv_ft128 = data["ft128"].to_numpy()
icrs_pv_ft512 = data["ft512"].to_numpy()
icrs_pv_bt32 = data["bt32"].to_numpy()
icrs_pv_bt128 = data["bt128"].to_numpy()
icrs_pv_bt512 = data["bt512"].to_numpy()

icrs_pv_ft32 = icrs_pv_ft32/batch_size
icrs_pv_ft128 = icrs_pv_ft128/batch_size
icrs_pv_ft512 = icrs_pv_ft512/batch_size
icrs_pv_bt32 = icrs_pv_bt32/batch_size
icrs_pv_bt128 = icrs_pv_bt128/batch_size
icrs_pv_bt512 = icrs_pv_bt512/batch_size

# %% [markdown]
# ## Figure 4

# %%
colors = ["tab:red", "tab:blue", "tab:orange", "tab:green"]

# %%
# plot best accuracies
fig, ax = plt.subplots()
ax.title.set_text('GC position')

ax.plot(
    samples, 
    gc_p_ba32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    samples, 
    gc_p_ba128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    samples, 
    gc_p_ba512, 
    linestyle="-.",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)

ax.set_xlabel(r'Sample number')
ax.set_ylabel(r'RMSE loss [km s$^{-1}$]')
ax.set_xscale('log')
#ax.set_ylim(0., 13.)
ax.set_ylim(-0.5, 27.)
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=2, fontsize=26)

plt.savefig(
    f"plots/1par_MLP_GC_position_loss_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show()

# %%
fig, ax = plt.subplots()
ax.title.set_text('GC position + velocity')

ax.plot(
    samples, 
    gc_pv_ba32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    samples, 
    gc_pv_ba128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    samples, 
    gc_pv_ba512, 
    linestyle="-.",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)

ax.set_xlabel(r'Sample number')
ax.set_ylabel(r'RMSE loss [km s$^{-1}$]')
ax.set_xscale('log')
#ax.set_ylim(0., 13.)
ax.set_ylim(-0.5, 27.)
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=2, fontsize=26)

plt.savefig(
    f"plots/1par_MLP_GC_position_velocity_loss_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show()

# %%
fig, ax = plt.subplots()
ax.title.set_text('ICRS position')

ax.plot(
    samples, 
    icrs_p_ba32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    samples, 
    icrs_p_ba128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    samples, 
    icrs_p_ba512, 
    linestyle="-.",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)

ax.set_xlabel(r'Sample number')
ax.set_ylabel(r'RMSE loss [km s$^{-1}$]')
ax.set_xscale('log')
#ax.set_ylim(0., 13.)
ax.set_ylim(-0.5, 27.)
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=2, fontsize=26)

plt.savefig(
    f"plots/1par_MLP_ICRS_position_loss_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show()

# %%
fig, ax = plt.subplots()
ax.title.set_text('ICRS position + velocity')

ax.plot(
    samples, 
    icrs_pv_ba32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    samples, 
    icrs_pv_ba128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    samples, 
    icrs_pv_ba512, 
    linestyle="-.",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)

ax.set_xlabel(r'Sample number')
ax.set_ylabel(r'RMSE loss [km s$^{-1}$]')
ax.set_xscale('log')
#ax.set_ylim(0., 13.)
ax.set_ylim(-0.5, 27.)
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=2, fontsize=26)

plt.savefig(
    f"plots/1par_MLP_ICRS_position_velocity_loss_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %% [markdown]
# ## Figure 13

# %%
# plot forward and backward timing 

fig, ax = plt.subplots()
ax.title.set_text('GC position')

ax.plot(
    batch_size, 
    gc_p_ft32, 
    linestyle="-",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    batch_size,
    gc_p_bt32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    zorder=0
)
ax.plot(
    batch_size,
    gc_p_ft128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    batch_size,
    gc_p_bt128, 
    linestyle="--",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
)
ax.plot(
    batch_size, 
    gc_p_ft512, 
    linestyle="-",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)
ax.plot(
    batch_size, 
    gc_p_bt512, 
    linestyle="--",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    zorder=0
)

ax.set_xlabel(r'Batch size')
ax.set_ylabel(r'Time [ms]')
ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(0.007, 7.)
ax.set_ylim(1.1e-3, 7.)
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=0, fontsize=26)

plt.savefig(
    f"plots/1par_MLP_GC_position_time_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %%
fig, ax = plt.subplots()
ax.title.set_text('GC position + velocity')

ax.plot(
    batch_size, 
    gc_pv_ft32, 
    linestyle="-",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    batch_size,
    gc_pv_bt32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    zorder=0
)
ax.plot(
    batch_size,
    gc_pv_ft128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    batch_size,
    gc_pv_bt128, 
    linestyle="--",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
)
ax.plot(
    batch_size, 
    gc_pv_ft512, 
    linestyle="-",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)
ax.plot(
    batch_size, 
    gc_pv_bt512, 
    linestyle="--",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    zorder=0
)

ax.set_xlabel(r'Batch size')
ax.set_ylabel(r'Time [ms]')
ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(0.007, 7.)
ax.set_ylim(1.1e-3, 7.)
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=0, fontsize=26)

plt.savefig(
    f"plots/1par_MLP_GC_position_velocity_time_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %%
fig, ax = plt.subplots()
ax.title.set_text('ICRS position')

ax.plot(
    batch_size,
    icrs_p_ft32, 
    linestyle="-",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    batch_size,
    icrs_p_bt32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    zorder=0
)
ax.plot(
    batch_size,
    icrs_p_ft128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    batch_size,
    icrs_p_bt128, 
    linestyle="--",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True
)
ax.plot(
    batch_size,
    icrs_p_ft512, 
    linestyle="-",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)
ax.plot(
    batch_size,
    icrs_p_bt512, 
    linestyle="--",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    zorder=0
)

ax.set_xlabel(r'Batch size')
ax.set_ylabel(r'Time [ms]')
ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(0.007, 7.)
ax.set_ylim(1.1e-3, 7.)
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())
#ax.yaxis.set_minor_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=0, fontsize=26)

plt.savefig(
    f"plots/1par_MLP_ICRS_position_time_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %%
fig, ax = plt.subplots()
ax.title.set_text('ICRS position + velocity')

ax.plot(
    batch_size,
    icrs_pv_ft32, 
    linestyle="-",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    batch_size,
    icrs_pv_bt32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    zorder=0
)
ax.plot(
    batch_size,
    icrs_pv_ft128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    batch_size, 
    icrs_pv_bt128, 
    linestyle="--",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True
)
ax.plot(
    batch_size,
    icrs_pv_ft512, 
    linestyle="-",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)
ax.plot(
    batch_size,
    icrs_pv_bt512, 
    linestyle="--",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    zorder=0
)

ax.set_xlabel(r'Batch size')
ax.set_ylabel(r'Time [ms]')
ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(0.007, 7.)
ax.set_ylim(1.1e-3, 7.)
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=0, fontsize=26)

plt.savefig(
    f"plots/1par_MLP_ICRS_position_velocity_time_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %% [markdown]
# # Convolutional neural network (CNN)

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/gc_p_cnn_accuracies.txt', sep=" ")
gc_p_ba32 = data["ba32"].to_numpy()
gc_p_ba128 = data["ba128"].to_numpy()
gc_p_ba512 = data["ba512"].to_numpy()

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/gc_pv_cnn_accuracies.txt', sep=" ")
gc_pv_ba32 = data["ba32"].to_numpy()
gc_pv_ba128 = data["ba128"].to_numpy()
gc_pv_ba512 = data["ba512"].to_numpy()

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/icrs_p_cnn_accuracies.txt', sep=" ")
icrs_p_ba32 = data["ba32"].to_numpy()
icrs_p_ba128 = data["ba128"].to_numpy()
icrs_p_ba512 = data["ba512"].to_numpy()

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/icrs_pv_cnn_accuracies.txt', sep=" ")
icrs_pv_ba32 = data["ba32"].to_numpy()
icrs_pv_ba128 = data["ba128"].to_numpy()
icrs_pv_ba512 = data["ba512"].to_numpy()

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/gc_p_cnn_timings.txt', sep=" ")
gc_p_ft32 = data["ft32"].to_numpy()
gc_p_ft128 = data["ft128"].to_numpy()
gc_p_ft512 = data["ft512"].to_numpy()
gc_p_bt32 = data["bt32"].to_numpy()
gc_p_bt128 = data["bt128"].to_numpy()
gc_p_bt512 = data["bt512"].to_numpy()

gc_p_ft32 = gc_p_ft32/batch_size
gc_p_ft128 = gc_p_ft128/batch_size
gc_p_ft512 = gc_p_ft512/batch_size
gc_p_bt32 = gc_p_bt32/batch_size
gc_p_bt128 = gc_p_bt128/batch_size
gc_p_bt512 = gc_p_bt512/batch_size

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/gc_pv_cnn_timings.txt', sep=" ")
gc_pv_ft32 = data["ft32"].to_numpy()
gc_pv_ft128 = data["ft128"].to_numpy()
gc_pv_ft512 = data["ft512"].to_numpy()
gc_pv_bt32 = data["bt32"].to_numpy()
gc_pv_bt128 = data["bt128"].to_numpy()
gc_pv_bt512 = data["bt512"].to_numpy()

gc_pv_ft32 = gc_pv_ft32/batch_size
gc_pv_ft128 = gc_pv_ft128/batch_size
gc_pv_ft512 = gc_pv_ft512/batch_size
gc_pv_bt32 = gc_pv_bt32/batch_size
gc_pv_bt128 = gc_pv_bt128/batch_size
gc_pv_bt512 = gc_pv_bt512/batch_size

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/icrs_p_cnn_timings.txt', sep=" ")
icrs_p_ft32 = data["ft32"].to_numpy()
icrs_p_ft128 = data["ft128"].to_numpy()
icrs_p_ft512 = data["ft512"].to_numpy()
icrs_p_bt32 = data["bt32"].to_numpy()
icrs_p_bt128 = data["bt128"].to_numpy()
icrs_p_bt512 = data["bt512"].to_numpy()

icrs_p_ft32 = icrs_p_ft32/batch_size
icrs_p_ft128 = icrs_p_ft128/batch_size
icrs_p_ft512 = icrs_p_ft512/batch_size
icrs_p_bt32 = icrs_p_bt32/batch_size
icrs_p_bt128 = icrs_p_bt128/batch_size
icrs_p_bt512 = icrs_p_bt512/batch_size

# %%
data = pd.read_csv('../../data/paper_results/ronchi_etal_2021/tests/maxwell_kick_tests/icrs_pv_cnn_timings.txt', sep=" ")
icrs_pv_ft32 = data["ft32"].to_numpy()
icrs_pv_ft128 = data["ft128"].to_numpy()
icrs_pv_ft512 = data["ft512"].to_numpy()
icrs_pv_bt32 = data["bt32"].to_numpy()
icrs_pv_bt128 = data["bt128"].to_numpy()
icrs_pv_bt512 = data["bt512"].to_numpy()

icrs_pv_ft32 = icrs_pv_ft32/batch_size
icrs_pv_ft128 = icrs_pv_ft128/batch_size
icrs_pv_ft512 = icrs_pv_ft512/batch_size
icrs_pv_bt32 = icrs_pv_bt32/batch_size
icrs_pv_bt128 = icrs_pv_bt128/batch_size
icrs_pv_bt512 = icrs_pv_bt512/batch_size

# %% [markdown]
# ## Figure 5

# %%
# plot best accuracies
fig, ax = plt.subplots()
ax.title.set_text('GC position')

ax.plot(
    samples, 
    gc_p_ba32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    samples, 
    gc_p_ba128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    samples, 
    gc_p_ba512, 
    linestyle="-.",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)

ax.set_xlabel(r'Sample number')
ax.set_ylabel(r'RMSE loss [km s$^{-1}$]')
ax.set_xscale('log')
#ax.set_ylim(0., 13.)
ax.set_ylim(-0.5, 27.)
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=2, fontsize=26)

plt.savefig(
    f"plots/1par_CNN_GC_position_CNN_loss_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %%
fig, ax = plt.subplots()
ax.title.set_text('GC position + velocity')

ax.plot(
    samples, 
    gc_pv_ba32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    samples, 
    gc_pv_ba128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    samples, 
    gc_pv_ba512, 
    linestyle="-.",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)

ax.set_xlabel(r'Sample number')
ax.set_ylabel(r'RMSE loss [km s$^{-1}$]')
ax.set_xscale('log')
#ax.set_ylim(0., 13.)
ax.set_ylim(-0.5, 27.)
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=2, fontsize=26)

plt.savefig(
    f"plots/1par_CNN_GC_position_velocity_loss_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %%
fig, ax = plt.subplots()
ax.title.set_text('ICRS position')

ax.plot(
    samples, 
    icrs_p_ba32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    samples, 
    icrs_p_ba128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    samples, 
    icrs_p_ba512, 
    linestyle="-.",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)

ax.set_xlabel(r'Sample number')
ax.set_ylabel(r'RMSE loss [km s$^{-1}$]')
ax.set_xscale('log')
#ax.set_ylim(0., 13.)
ax.set_ylim(-0.5, 27.)
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=2, fontsize=26)

plt.savefig(
    f"plots/1par_CNN_ICRS_position_loss_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %%
fig, ax = plt.subplots()
ax.title.set_text('ICRS position + velocity')

ax.plot(
    samples, 
    icrs_pv_ba32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    samples, 
    icrs_pv_ba128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    samples, 
    icrs_pv_ba512, 
    linestyle="-.",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)

ax.set_xlabel(r'Sample number')
ax.set_ylabel(r'RMSE loss [km s$^{-1}$]')
ax.set_xscale('log')
#ax.set_ylim(0., 13.)
ax.set_ylim(-0.5, 27.)
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=2, fontsize=26)

plt.savefig(
    f"plots/1par_CNN_ICRS_position_velocity_loss_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %% [markdown]
# ## Figure 14

# %%
# plot forward and backward timing 

fig, ax = plt.subplots()
ax.title.set_text('GC position')

ax.plot(
    batch_size, 
    gc_p_ft32, 
    linestyle="-",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    batch_size,
    gc_p_bt32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    zorder=0
)
ax.plot(
    batch_size,
    gc_p_ft128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    batch_size,
    gc_p_bt128, 
    linestyle="--",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
)
ax.plot(
    batch_size, 
    gc_p_ft512, 
    linestyle="-",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)
ax.plot(
    batch_size, 
    gc_p_bt512, 
    linestyle="--",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    zorder=0
)

ax.set_xlabel(r'Batch size')
ax.set_ylabel(r'Time [ms]')
ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(0.007, 7.)
ax.set_ylim(1.1e-3, 7.)
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=0, fontsize=26)

plt.savefig(
    f"plots/1par_CNN_GC_position_time_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %%
fig, ax = plt.subplots()
ax.title.set_text('GC position + velocity')

ax.plot(
    batch_size, 
    gc_pv_ft32, 
    linestyle="-",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    batch_size,
    gc_pv_bt32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    zorder=0
)
ax.plot(
    batch_size,
    gc_pv_ft128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    batch_size,
    gc_pv_bt128, 
    linestyle="--",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
)
ax.plot(
    batch_size, 
    gc_pv_ft512, 
    linestyle="-",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)
ax.plot(
    batch_size, 
    gc_pv_bt512, 
    linestyle="--",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    zorder=0
)

ax.set_xlabel(r'Batch size')
ax.set_ylabel(r'Time [ms]')
ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(0.007, 7.)
ax.set_ylim(1.1e-3, 7.)
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=0, fontsize=26)

plt.savefig(
    f"plots/1par_CNN_GC_position_velocity_time_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %%
fig, ax = plt.subplots()
ax.title.set_text('ICRS position')

ax.plot(
    batch_size,
    icrs_p_ft32, 
    linestyle="-",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    batch_size,
    icrs_p_bt32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    zorder=0
)
ax.plot(
    batch_size,
    icrs_p_ft128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    batch_size,
    icrs_p_bt128, 
    linestyle="--",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True
)
ax.plot(
    batch_size,
    icrs_p_ft512, 
    linestyle="-",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)
ax.plot(
    batch_size,
    icrs_p_bt512, 
    linestyle="--",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    zorder=0
)

ax.set_xlabel(r'Batch size')
ax.set_ylabel(r'Time [ms]')
ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(0.007, 7.)
ax.set_ylim(1.1e-3, 7.)
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())
#ax.yaxis.set_minor_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=0, fontsize=26)

plt.savefig(
    f"plots/1par_CNN_ICRS_position_time_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)

# %%
fig, ax = plt.subplots()
ax.title.set_text('ICRS position + velocity')

ax.plot(
    batch_size,
    icrs_pv_ft32, 
    linestyle="-",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    label=r"32",
    zorder=0 
)
ax.plot(
    batch_size,
    icrs_pv_bt32, 
    linestyle="--",
    linewidth=5,
    color=colors[0],
    alpha=0.9,
    rasterized=True,
    zorder=0
)
ax.plot(
    batch_size,
    icrs_pv_ft128, 
    linestyle="-",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True,
    label=r"128" 
)
ax.plot(
    batch_size, 
    icrs_pv_bt128, 
    linestyle="--",
    linewidth=5,
    color=colors[1],
    alpha=0.9,
    rasterized=True
)
ax.plot(
    batch_size,
    icrs_pv_ft512, 
    linestyle="-",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    label=r"512",
    zorder=0 
)
ax.plot(
    batch_size,
    icrs_pv_bt512, 
    linestyle="--",
    linewidth=5,
    color=colors[2],
    alpha=0.9,
    rasterized=True,
    zorder=0
)

ax.set_xlabel(r'Batch size')
ax.set_ylabel(r'Time [ms]')
ax.set_xscale('log')
ax.set_yscale('log')
#ax.set_ylim(0.007, 7.)
ax.set_ylim(1.1e-3, 7.)
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())
ax.legend(frameon=False, loc=0, fontsize=26)

plt.savefig(
    f"plots/1par_CNN_ICRS_position_velocity_time_test.pdf",
    dpi=300,
    bbox_inches="tight",
)
plt.show(block=False)
